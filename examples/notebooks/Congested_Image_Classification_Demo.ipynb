# %%
import tensorflow
from deeputil.model import ModelsMaster
from deeputil.modelassist import KerasModelHelper
# Out:
# Using TensorFlow backend.

# %%
v16 = ModelsMaster.get_inceptionV3_model()
# Out:
# VGG16 model is ~0.5GB, make sure you have time and space...

# %%
KerasModelHelper.get_model_input_image_shape_info(v16)
# Out:
# Now getting very first layer from model..
# The layer Input Shape is (None, 224, 224, 3)
# You would need to import image of this size - (224, 224, 3)
# (None, 224, 224, 3)

# %%
image = "/Users/avkashchauhan/learn/workshop2017/recognize-me.jpg"

# %%
from deeputil.imageassist import ImageUtils

# %%
ImageUtils.display_image_from_disk(image)
img = ImageUtils.import_image_from_disk(image, (224,224), isGray= False)
img_array = ImageUtils.convert_image_array(img)
img_p = ImageUtils.preprocess_image_array(img_array)
# Out:
# Now importing selected image from the disk with default size (256, 256) ...
# Now importing selected image from the disk...
# Image as array shape:
# Now pre-processing the image to get ready for classification..

# %%
KerasModelHelper.get_model_layers_details_all(v16)
# Out:
# Collecting layer count.....
# Total 23 layers details are collected.
#     Id     LayerName          Type Filters             InputShape  \
# 0    0       input_1    InputLayer       0    (None, 224, 224, 3)
# 1    1  block1_conv1        Conv2D      64    (None, 224, 224, 3)
# 2    2  block1_conv2        Conv2D      64   (None, 224, 224, 64)
# 3    3   block1_pool  MaxPooling2D       0   (None, 224, 224, 64)
# 4    4  block2_conv1        Conv2D     128   (None, 112, 112, 64)
# 5    5  block2_conv2        Conv2D     128  (None, 112, 112, 128)
# 6    6   block2_pool  MaxPooling2D       0  (None, 112, 112, 128)
# 7    7  block3_conv1        Conv2D     256    (None, 56, 56, 128)
# 8    8  block3_conv2        Conv2D     256    (None, 56, 56, 256)
# 9    9  block3_conv3        Conv2D     256    (None, 56, 56, 256)
# 10  10   block3_pool  MaxPooling2D       0    (None, 56, 56, 256)
# 11  11  block4_conv1        Conv2D     512    (None, 28, 28, 256)
# 12  12  block4_conv2        Conv2D     512    (None, 28, 28, 512)
# 13  13  block4_conv3        Conv2D     512    (None, 28, 28, 512)
# 14  14   block4_pool  MaxPooling2D       0    (None, 28, 28, 512)
# 15  15  block5_conv1        Conv2D     512    (None, 14, 14, 512)
# 16  16  block5_conv2        Conv2D     512    (None, 14, 14, 512)
# 17  17  block5_conv3        Conv2D     512    (None, 14, 14, 512)
# 18  18   block5_pool  MaxPooling2D       0    (None, 14, 14, 512)
# 19  19       flatten       Flatten       0      (None, 7, 7, 512)
# 20  20           fc1         Dense       0          (None, 25088)
# 21  21           fc2         Dense       0           (None, 4096)
# 22  22   predictions         Dense       0           (None, 4096)
#
#               OutputShape Activation ParameterCount
# 0     (None, 224, 224, 3)       None              0
# 1    (None, 224, 224, 64)       relu           1792
# 2    (None, 224, 224, 64)       relu          36928
# 3    (None, 112, 112, 64)       None              0
# 4   (None, 112, 112, 128)       relu          73856
# 5   (None, 112, 112, 128)       relu         147584
# 6     (None, 56, 56, 128)       None              0
# 7     (None, 56, 56, 256)       relu         295168
# 8     (None, 56, 56, 256)       relu         590080
# 9     (None, 56, 56, 256)       relu         590080
# 10    (None, 28, 28, 256)       None              0
# 11    (None, 28, 28, 512)       relu        1180160
# 12    (None, 28, 28, 512)       relu        2359808
# 13    (None, 28, 28, 512)       relu        2359808
# 14    (None, 14, 14, 512)       None              0
# 15    (None, 14, 14, 512)       relu        2359808
# 16    (None, 14, 14, 512)       relu        2359808
# 17    (None, 14, 14, 512)       relu        2359808
# 18      (None, 7, 7, 512)       None              0
# 19          (None, 25088)       None              0
# 20           (None, 4096)       relu      102764544
# 21           (None, 4096)       relu       16781312
# 22           (None, 1000)    softmax        4097000

# %%
KerasModelHelper.get_model_layers_details_all_extended(v16, img_p, show_info=False)
# Out:
#     Id     LayerName          Type Filters             InputShape  \
# 0    0       input_1    InputLayer     NaN    (None, 224, 224, 3)
# 1    1  block1_conv1        Conv2D      64    (None, 224, 224, 3)
# 2    2  block1_conv2        Conv2D      64   (None, 224, 224, 64)
# 3    3   block1_pool  MaxPooling2D     NaN   (None, 224, 224, 64)
# 4    4  block2_conv1        Conv2D     128   (None, 112, 112, 64)
# 5    5  block2_conv2        Conv2D     128  (None, 112, 112, 128)
# 6    6   block2_pool  MaxPooling2D     NaN  (None, 112, 112, 128)
# 7    7  block3_conv1        Conv2D     256    (None, 56, 56, 128)
# 8    8  block3_conv2        Conv2D     256    (None, 56, 56, 256)
# 9    9  block3_conv3        Conv2D     256    (None, 56, 56, 256)
# 10  10   block3_pool  MaxPooling2D     NaN    (None, 56, 56, 256)
# 11  11  block4_conv1        Conv2D     512    (None, 28, 28, 256)
# 12  12  block4_conv2        Conv2D     512    (None, 28, 28, 512)
# 13  13  block4_conv3        Conv2D     512    (None, 28, 28, 512)
# 14  14   block4_pool  MaxPooling2D     NaN    (None, 28, 28, 512)
# 15  15  block5_conv1        Conv2D     512    (None, 14, 14, 512)
# 16  16  block5_conv2        Conv2D     512    (None, 14, 14, 512)
# 17  17  block5_conv3        Conv2D     512    (None, 14, 14, 512)
# 18  18   block5_pool  MaxPooling2D     NaN    (None, 14, 14, 512)
# 19  19       flatten       Flatten     NaN      (None, 7, 7, 512)
# 20  20           fc1         Dense     NaN          (None, 25088)
# 21  21           fc2         Dense     NaN           (None, 4096)
# 22  22   predictions         Dense     NaN           (None, 4096)
#
#               OutputShape Activation ParameterCount           Act_Shape  \
# 0     (None, 224, 224, 3)       None              0    (1, 224, 224, 3)
# 1    (None, 224, 224, 64)       relu           1792   (1, 224, 224, 64)
# 2    (None, 224, 224, 64)       relu          36928   (1, 224, 224, 64)
# 3    (None, 112, 112, 64)       None              0   (1, 112, 112, 64)
# 4   (None, 112, 112, 128)       relu          73856  (1, 112, 112, 128)
# 5   (None, 112, 112, 128)       relu         147584  (1, 112, 112, 128)
# 6     (None, 56, 56, 128)       None              0    (1, 56, 56, 128)
# 7     (None, 56, 56, 256)       relu         295168    (1, 56, 56, 256)
# 8     (None, 56, 56, 256)       relu         590080    (1, 56, 56, 256)
# 9     (None, 56, 56, 256)       relu         590080    (1, 56, 56, 256)
# 10    (None, 28, 28, 256)       None              0    (1, 28, 28, 256)
# 11    (None, 28, 28, 512)       relu        1180160    (1, 28, 28, 512)
# 12    (None, 28, 28, 512)       relu        2359808    (1, 28, 28, 512)
# 13    (None, 28, 28, 512)       relu        2359808    (1, 28, 28, 512)
# 14    (None, 14, 14, 512)       None              0    (1, 14, 14, 512)
# 15    (None, 14, 14, 512)       relu        2359808    (1, 14, 14, 512)
# 16    (None, 14, 14, 512)       relu        2359808    (1, 14, 14, 512)
# 17    (None, 14, 14, 512)       relu        2359808    (1, 14, 14, 512)
# 18      (None, 7, 7, 512)       None              0      (1, 7, 7, 512)
# 19          (None, 25088)       None              0          (1, 25088)
# 20           (None, 4096)       relu      102764544           (1, 4096)
# 21           (None, 4096)       relu       16781312           (1, 4096)
# 22           (None, 1000)    softmax        4097000           (1, 1000)
#
#    FeatureMapSize FeatureMapCount
# 0        (224, 3)               3
# 1       (224, 64)              64
# 2       (224, 64)              64
# 3       (112, 64)              64
# 4      (112, 128)             128
# 5      (112, 128)             128
# 6       (56, 128)             128
# 7       (56, 256)             256
# 8       (56, 256)             256
# 9       (56, 256)             256
# 10      (28, 256)             256
# 11      (28, 512)             512
# 12      (28, 512)             512
# 13      (28, 512)             512
# 14      (14, 512)             512
# 15      (14, 512)             512
# 16      (14, 512)             512
# 17      (14, 512)             512
# 18       (7, 512)             512
# 19            NaN             NaN
# 20            NaN             NaN
# 21            NaN             NaN
# 22            NaN             NaN

# %%
KerasModelHelper.get_feature_map_counts_for_all_layers(v16, img_p)
# Out:
# Now collecting feature maps for all layers in the given model..
# Feature maps for all 23 layers are collected.
#    LayerId FeatureMapCount
# 0        0               3
# 1        1              64
# 2        2              64
# 3        3              64
# 4        4             128
# 5        5             128
# 6        6             128
# 7        7             256
# 8        8             256
# 9        9             256
# 10      10             256
# 11      11             512
# 12      12             512
# 13      13             512
# 14      14             512
# 15      15             512
# 16      16             512
# 17      17             512
# 18      18             512
# 19      19             NaN
# 20      20             NaN
# 21      21             NaN
# 22      22             NaN

# %%
KerasModelHelper.display_full_feature_map_for_selected_layer_in_model(v16, 0, img_p, show_info=False)

# %%
KerasModelHelper.display_full_feature_map_for_selected_layer_in_model(v16, 1, img_p, show_info=False)

# %%
KerasModelHelper.display_full_feature_map_for_selected_layer_in_model(v16, 2, img_p, show_info=False)

# %%
KerasModelHelper.display_full_feature_map_for_selected_layer_in_model(v16, 6, img_p, show_info=False)

# %%
KerasModelHelper.display_individual_feature_for_selected_layer_in_model(v16,1, 61, img_p)
# Out:
# Now collecting feature map for the selected layer in the given model..
# You are watching feature map #61 from the layer #1.

# %%
KerasModelHelper.display_individual_feature_for_selected_layer_in_model(v16,1, 52, img_p)
# Out:
# Now collecting feature map for the selected layer in the given model..
# You are watching feature map #52 from the layer #1.

# %%
KerasModelHelper.display_individual_feature_for_selected_layer_in_model(v16,1, 59, img_p)
# Out:
# Now collecting feature map for the selected layer in the given model..
# You are watching feature map #59 from the layer #1.
