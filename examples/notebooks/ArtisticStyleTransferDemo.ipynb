# %%
from PIL import Image
from deeputil.cnnart import NeuralStyle
# Out:
# Using TensorFlow backend.

# %%
height=512
width=512
input_url = '/Users/avkashchauhan/Downloads/hugo.png'
style_url = '/Users/avkashchauhan/Downloads/wave.png'
#input_url = '/Users/avkashchauhan/Downloads/slide.png'
#style_url = '/Users/avkashchauhan/Downloads/yellow_style.png'

# %%
Image.open(input_url)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x105E77748>

# %%
Image.open(style_url)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x105E053C8>

# %%
img = NeuralStyle.createNeuralDesign(height, width, input_url, style_url, iteration_count=1 )
# Out:
# Now importing selected input image from the disk...
# Now converting input image into numpy array..
# The input image shape is (1, 512, 512, 3).
# Now importing selected style image from the disk...
# Now converting style image into numpy array..
# The style image shape is (1, 512, 512, 3).
# Now transforming both style and input image numpy array as below:
# [1] Subtract the mean RGB value from each pixel
# [2] Flip the ordering of the multi-dimensional array from RGB to BGR
# Both style and input image numpy array are transformed:
# Now combing both style and input image array into a tensor.
# Now getting VGG16 Keras model without flatten layers..
# VGG16 model is ~0.5GB, make sure you have time and space...
# Verifying all layers from the model:
# ...
# Total 19 layers details are collected.
#     Id     LayerName          Type Filters               InputShape  \
# 0    0       input_1    InputLayer       0    (None, None, None, 3)
# ...

# %%
final_img = NeuralStyle.processStyledImageForView(img, height, width, show_info=True)
# Out:
# Now processing input styles image, ready to view!
# Done!!!

# %%
Image.fromarray(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x105E5FDD8>

# %%
Image.fromarray(final_img)
