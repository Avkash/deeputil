# %%
from deeputil.datasets import AutoMpg
# Out:
# Using TensorFlow backend.

# %%
df = AutoMpg.load_data_as_pandas_df()
# Out:
# Downloaded 14 KB dataset with 398 rows and 8 columns..........

# %%
df.shape
# Out:
# (398, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      cylinders  displacement horsepower  weight  acceleration  modelyear  \
# 0            8         307.0      130.0  3504.0          12.0         70
# 1            8         350.0      165.0  3693.0          11.5         70
# 2            8         318.0      150.0  3436.0          11.0         70
# 3            8         304.0      150.0  3433.0          12.0         70
# 4            8         302.0      140.0  3449.0          10.5         70
# 5            8         429.0      198.0  4341.0          10.0         70
# 6            8         454.0      220.0  4354.0           9.0         70
# 7            8         440.0      215.0  4312.0           8.5         70
# 8            8         455.0      225.0  4425.0          10.0         70
# 9            8         390.0      190.0  3850.0           8.5         70
# 10           8         383.0      170.0  3563.0          10.0         70
# ...
