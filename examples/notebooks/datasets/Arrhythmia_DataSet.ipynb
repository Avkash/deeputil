# %%
from deeputil.datasets import Arrhythmia
# Out:
# Using TensorFlow backend.

# %%
df = Arrhythmia.load_data_as_pandas_df()
# Out:
# Downloaded 393 KB dataset with 451 rows and 280 columns..........

# %%
df.shape
# Out:
# (451, 280)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      75  0  190  80   91  193  371  174  121  -16 ... 0.0.38   9.0  -0.9  \
# 0    56  1  165  64   81  174  401  149   39   25 ...    0.0   8.5   0.0
# 1    54  0  172  95  138  163  386  185  102   96 ...    0.0   9.5  -2.4
# 2    55  0  175  94  100  202  380  179  143   28 ...    0.0  12.2  -2.2
# 3    75  0  190  80   88  181  360  177  103  -16 ...    0.0  13.1  -3.6
# 4    13  0  169  51  100  167  321  174   91  107 ...   -0.6  12.2  -2.8
# 5    40  1  160  52   77  129  377  133   77   77 ...    0.0   6.5   0.0
# 6    49  1  162  54   78    0  376  157   70   67 ...    0.0   8.2  -1.9
# 7    44  0  168  56   84  118  354  160   63   61 ...    0.0   7.0  -1.3
# 8    50  1  167  67   89  130  383  156   73   85 ...   -0.6  10.8  -1.7
# 9    62  0  170  72  102  135  401  156   83   72 ...   -0.5   9.0  -2.0
# 10   45  1  165  86   77  143  373  150   65   12 ...    0.0   4.4  -2.2
# ...
