# %%
from deeputil.datasets import USCommunities
# Out:
# Using TensorFlow backend.

# %%
df = USCommunities.load_data_as_pandas_df()
# Out:
# Downloaded 1.0 MB dataset with 1994 and 127 columns..........

# %%
df.shape
# Out:
# (1994, 127)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       state county community  fold  population  householdsize  racepctblack  \
# 0         8      ?         ?     1        0.19           0.33          0.02
# 1        53      ?         ?     1        0.00           0.16          0.12
# 2        24      ?         ?     1        0.00           0.42          0.49
# 3        34      5     81440     1        0.04           0.77          1.00
# 4        42     95      6096     1        0.01           0.55          0.02
# 5         6      ?         ?     1        0.02           0.28          0.06
# 6        44      7     41500     1        0.01           0.39          0.00
# 7         6      ?         ?     1        0.01           0.74          0.03
# 8        21      ?         ?     1        0.03           0.34          0.20
# 9        29      ?         ?     1        0.01           0.40          0.06
# 10        6      ?         ?     1        0.13           0.71          0.15
# ...
