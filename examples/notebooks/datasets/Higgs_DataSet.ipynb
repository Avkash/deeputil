# %%
from deeputil.datasets import Higgs
# Out:
# Using TensorFlow backend.

# %%
df = Higgs.load_data_as_pandas_df()
# Out:
# Downloaded 8.6 MB dataset with 15000 and 29 columns..........

# %%
df.shape
# Out:
# (15000, 29)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        response        x1        x2        x3        x4        x5        x6  \
# 0           1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202
# 1           1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531
# 2           1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875
# 3           0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066
# 4           1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466
# 5           0.0  1.595839 -0.607811  0.007075  1.818450 -0.111906  0.847550
# 6           1.0  0.409391 -1.884684 -1.027292  1.672452 -1.604598  1.338015
# 7           1.0  0.933895  0.629130  0.527535  0.238033 -0.966569  0.547811
# 8           1.0  1.405144  0.536603  0.689554  1.179567 -0.110061  3.202405
# 9           1.0  1.176566  0.104161  1.397002  0.479721  0.265513  1.135563
# 10          1.0  0.945974  1.111244  1.218337  0.907639  0.821537  1.153243
# ...
