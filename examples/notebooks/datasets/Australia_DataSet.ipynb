# %%
from deeputil.datasets import Australia
# Out:
# Using TensorFlow backend.

# %%
df = Australia.load_data_as_pandas_df()
# Out:
# Downloaded 12 KB dataset with 251 and 8 columns..........

# %%
df.shape
# Out:
# (251, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      premax  salmax  minairtemp  maxairtemp  maxsst  maxsoilmoist  Max_czcs  \
# 0    350.00    3448       287.0       301.5  302817          6.39      0.51
# 1    350.00    3487       290.0       301.2  302280          0.00      0.80
# 2    450.00    3483       289.0       301.0  303326          1.00      1.25
# 3    378.57    3467       286.0       302.0  303122          7.00      1.65
# 4    350.00    3459       288.0       301.0  302890          5.00      1.53
# 5    375.00    3472       287.0       302.0  302767          9.00      0.75
# 6    435.71    3481       288.1       302.3  302750          0.00      0.82
# 7    435.71    3483       288.9       302.4  302733          0.00      0.82
# 8    450.00    3480       289.0       302.0  302775          9.00      0.97
# 9    350.00    3467       289.9       301.4  302847          0.00      0.68
# 10   350.00    3482       290.0       301.0  302422         14.00      1.11
# ...
