# %%
from deeputil.datasets import CreditCardCustomers
# Out:
# Using TensorFlow backend.

# %%
df = CreditCardCustomers.load_data_as_pandas_df()
# Out:
# Downloaded 2.8 MB dataset with 30000 rows and 25 columns..........

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# 6          7     500000    1          1         2   29      0      0      0
# 7          8     100000    2          2         2   23      0     -1     -1
# 8          9     140000    2          3         1   28      0      0      2
# 9         10      20000    1          3         2   35     -2     -2     -2
# 10        11     200000    2          3         2   34      0      0      2
# ...
