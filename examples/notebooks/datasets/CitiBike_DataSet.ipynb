# %%
from deeputil.datasets import CitiBike
# Out:
# Using TensorFlow backend.

# %%
df = CitiBike.load_data_as_pandas_df()
# Out:
# Downloaded  3.1 MB dataset with 20000 rows and 15 columns..........

# %%
df.shape
# Out:
# (20000, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        tripduration      starttime       stoptime  start station id  \
# 0               554  1372665206000  1372665760000               404
# 1               557  1372688898000  1372689455000               490
# 2               237  1372689607000  1372689844000               153
# 3              1273  1372690132000  1372691405000               480
# 4               551  1372690839000  1372691390000               516
# 5               567  1372691853000  1372692420000               545
# 6               883  1372693765000  1372694648000               510
# 7               256  1372694242000  1372694498000               168
# 8               984  1372694563000  1372695547000               327
# 9              1620  1372695803000  1372697423000               524
# 10              332  1372696443000  1372696775000               306
# 11             1936  1372696494000  1372698430000               315
# ...
