# %%
from deeputil.datasets import Airline
# Out:
# Using TensorFlow backend.

# %%
df = Airline.load_airlines_base_data_as_pandas_df()
# Out:
# Downloaded 1.3 MB dataset with 699 and 11 columns..........

# %%
df.shape
# Out:
# (27112, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       IsDepDelayed  fYear fMonth fDayofMonth fDayOfWeek UniqueCarrier Origin  \
# 0              YES  f1987    f10         f14         f3            PS    SAN
# 1               NO  f1987    f10         f18         f7            PS    SAN
# 2              YES  f1987    f10         f19         f1            PS    SAN
# 3               NO  f1987    f10         f21         f3            PS    SAN
# 4              YES  f1987    f10         f23         f5            PS    SAN
# 5              YES  f1987    f10         f24         f6            PS    SAN
# 6               NO  f1987    f10         f25         f7            PS    SAN
# 7              YES  f1987    f10         f26         f1            PS    SAN
# 8              YES  f1987    f10         f28         f3            PS    SAN
# 9              YES  f1987    f10         f29         f4            PS    SAN
# 10             YES  f1987    f10         f31         f6            PS    SAN
# ...

# %%
df2 = Airline.load_airlines_1987_2008_data_as_pandas_df()
# Out:
# Downloaded 4.4 MB dataset with 43978 and 31 columns..........
# /Users/avkashchauhan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df2.shape
# Out:
# (43978, 31)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      1987     10          14          3    741.0         730    912.0
# 1      1987     10          15          4    729.0         730    903.0
# 2      1987     10          17          6    741.0         730    918.0
# 3      1987     10          18          7    729.0         730    847.0
# 4      1987     10          19          1    749.0         730    922.0
# 5      1987     10          21          3    728.0         730    848.0
# 6      1987     10          22          4    728.0         730    852.0
# 7      1987     10          23          5    731.0         730    902.0
# 8      1987     10          24          6    744.0         730    908.0
# 9      1987     10          25          7    729.0         730    851.0
# 10     1987     10          26          1    735.0         730    904.0
# 11     1987     10          28          3    741.0         725    919.0
# ...
