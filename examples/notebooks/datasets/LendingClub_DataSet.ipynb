# %%
from deeputil.datasets import LendingClub
# Out:
# Using TensorFlow backend.

# %%
df1 = LendingClub.load_10K_records_data_as_pandas_df()
# Out:
# Downloaded 6.8 MB dataset with 10000 and 52 columns..........

# %%
df1.shape
# Out:
# (10000, 52)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0      676051   863983.0    12000.0      12000.0     12000.000000   36 months
# 1      730450   926409.0     6000.0       6000.0      6000.000000   36 months
# 2      718831   913101.0    10000.0      10000.0     10000.000000   36 months
# 3      593040   761591.0    11200.0      11200.0     10755.100000   36 months
# 4      811445  1018474.0     5600.0       5600.0      5575.000000   36 months
# 5      445524   543325.0     5600.0       5600.0      5600.000000   36 months
# 6      259414   259403.0     3975.0       3975.0      1925.000000   36 months
# 7      447858   548913.0    20000.0      20000.0     19602.950000   36 months
# 8     1033679  1263255.0     4800.0       4800.0      4800.000000   36 months
# 9      320072   320067.0    25000.0      18000.0      5500.000000   36 months
# 10     613297   786330.0    15000.0      15000.0     15000.000000   36 months
# ...

# %%
df2 = LendingClub.load_full_data_as_pandas_df()
# Out:
# Downloaded 32 MB dataset with 42538 and 52 columns..........
# /Users/avkashchauhan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df2.shape
# Out:
# (42538, 52)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of                                                     id  member_id  loan_amnt  \
# 0                                              1077501  1296599.0     5000.0
# 1                                              1077430  1314167.0     2500.0
# 2                                              1077175  1313524.0     2400.0
# 3                                              1076863  1277178.0    10000.0
# 4                                              1075358  1311748.0     3000.0
# 5                                              1075269  1311441.0     5000.0
# 6                                              1069639  1304742.0     7000.0
# 7                                              1072053  1288686.0     3000.0
# 8                                              1071795  1306957.0     5600.0
# 9                                              1071570  1306721.0     5375.0
# 10                                             1070078  1305201.0     6500.0
# ...
