# %%
from deeputil.datasets import Chicago
# Out:
# Using TensorFlow backend.

# %%
df1 = Chicago.load_chicago_census_data_as_pandas_df()
# Out:
# Downloaded 3.8 KB dataset with 78 and 9 columns..........

# %%
df1.shape
# Out:
# (78, 9)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of     Community Area Number     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0             Rogers Park                         7.7
# 1                     2.0              West Ridge                         7.8
# 2                     3.0                  Uptown                         3.8
# 3                     4.0          Lincoln Square                         3.4
# 4                     5.0            North Center                         0.3
# 5                     6.0               Lake View                         1.1
# 6                     7.0            Lincoln Park                         0.8
# 7                     8.0         Near North Side                         1.9
# 8                     9.0             Edison Park                         1.1
# 9                    10.0            Norwood Park                         2.0
# 10                   11.0          Jefferson Park                         2.7
# ...

# %%
df2 = Chicago.load_chicago_crimes_data_as_pandas_df()
# Out:
# Downloaded 2.3 MB dataset with 9999 and 22 columns..........

# %%
df2.shape
# Out:
# (9999, 22)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of            ID Case Number                    Date  \
# 0     9955810    HY144797  02/08/2015 11:43:40 PM
# 1     9955861    HY144838  02/08/2015 11:41:42 PM
# 2     9955801    HY144779  02/08/2015 11:30:22 PM
# 3     9956197    HY144787  02/08/2015 11:30:23 PM
# 4     9955846    HY144829  02/08/2015 11:30:58 PM
# 5     9955835    HY144778  02/08/2015 11:30:21 PM
# 6     9955872    HY144822  02/08/2015 11:27:24 PM
# 7       21752    HY144738  02/08/2015 11:26:12 PM
# 8     9955808    HY144775  02/08/2015 11:20:33 PM
# 9     9958275    HY146732  02/08/2015 11:15:36 PM
# 10    9955845    HY144771  02/08/2015 11:10:44 PM
# 11    9957101    HY145714  02/08/2015 11:00:22 PM
# 12    9957147    HY145922  02/08/2015 11:00:39 PM
# 13    9956169    HY145063  02/08/2015 11:00:43 PM
# 14    9957473    HY146316  02/08/2015 11:00:49 PM
# 15    9955826    HY144769  02/08/2015 11:00:23 PM
# 16    9955767    HY144745  02/08/2015 10:47:35 PM
# ...
