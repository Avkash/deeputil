# %% [markdown]
# # Importing prebuilt CIFAR10 Model
#
# Model Details:
#  - Trained for 250 epochs
#  - Accuracy 78.00%
#
# Once model is loaded it like any other Keras model, ready to work!

# %%
import tensorflow
from deeputil.model import ModelsMaster
from deeputil.modelassist import KerasModelHelper
# Out:
# Using TensorFlow backend.

# %%
cifar10 = ModelsMaster.get_cifar10_model()
# Out:
# This pre-built CIFAR10 model is about 20MB and will be downloaded from the internet...
# Losses: categorical_crossentropy
# Optimizers: rmsprop
# Metrics: ['acc']
# Loading model json from the disk done..
# Loading model weights from the disk done.

# %%
KerasModelHelper.get_model_layers_details_all(cifar10)
# Out:
# ...
# Total 18 layers details are collected.
#     Id        LayerName          Type Filters          InputShape  \
# 0    0         conv2d_1        Conv2D      32   (None, 32, 32, 3)
# 1    1     activation_1    Activation       0  (None, 32, 32, 32)
# 2    2         conv2d_2        Conv2D      32  (None, 32, 32, 32)
# 3    3     activation_2    Activation       0  (None, 30, 30, 32)
# 4    4  max_pooling2d_1  MaxPooling2D       0  (None, 30, 30, 32)
# 5    5        dropout_1       Dropout       0  (None, 15, 15, 32)
# 6    6         conv2d_3        Conv2D      64  (None, 15, 15, 32)
# 7    7     activation_3    Activation       0  (None, 15, 15, 64)
# 8    8         conv2d_4        Conv2D      64  (None, 15, 15, 64)
# 9    9     activation_4    Activation       0  (None, 13, 13, 64)
# 10  10  max_pooling2d_2  MaxPooling2D       0  (None, 13, 13, 64)
# 11  11        dropout_2       Dropout       0    (None, 6, 6, 64)
# 12  12        flatten_1       Flatten       0    (None, 6, 6, 64)
# ...

# %%
KerasModelHelper.get_model_summary(cifar10)
# Out:
# Generating model summary for the model....
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# ...
