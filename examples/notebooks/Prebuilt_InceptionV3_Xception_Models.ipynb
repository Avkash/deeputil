# %%
import tensorflow
import keras
from deeputil.model import ModelsMaster
from deeputil.modelassist import KerasModelHelper
from deeputil.modelassist import ImportExport
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Getting Google Inception V3 Model
#
# Details: https://research.googleblog.com/2016/03/train-your-own-image-classifier-with.html

# %% [markdown]
# ![Google Inception V3 Model]("https://github.com/Avkash/mldl/blob/master/images/google-inception-v3.png")

# %%
inceptionV3 = ModelsMaster.get_inceptionV3_model()
# Out:
# Inception V3 model is ~0.5GB, make sure you have time and space...

# %%
assert isinstance(inceptionV3, keras.engine.training.Model)

# %%
KerasModelHelper.get_model_layers_details_all(inceptionV3)
# Out:
# ...
# Total 313 layers details are collected.
#       Id               LayerName                    Type Filters  \
# 0      0                 input_1              InputLayer       0
# 1      1                conv2d_1                  Conv2D      32
# 2      2   batch_normalization_1      BatchNormalization       0
# 3      3            activation_1              Activation       0
# 4      4                conv2d_2                  Conv2D      32
# 5      5   batch_normalization_2      BatchNormalization       0
# 6      6            activation_2              Activation       0
# 7      7                conv2d_3                  Conv2D      64
# 8      8   batch_normalization_3      BatchNormalization       0
# 9      9            activation_3              Activation       0
# 10    10         max_pooling2d_1            MaxPooling2D       0
# 11    11                conv2d_4                  Conv2D      80
# 12    12   batch_normalization_4      BatchNormalization       0
# ...

# %% [markdown]
# # Getting Xception Model
#
# URL: https://arxiv.org/abs/1610.02357
#
# More Details:
# https://www.semanticscholar.org/paper/Xception-Deep-Learning-with-Depthwise-Separable-Co-Chollet/34c8698207bc8440666e86e274deec0d1231c366

# %%
xception = ModelsMaster.get_xception_model()
# Out:
# Xception model is ~0.5GB, make sure you have time and space...

# %%
assert isinstance(xception, keras.engine.training.Model)

# %%
KerasModelHelper.get_model_layers_count(xception)
# Out:
# Calculating model layers...
# Total layers in this model are : 134
# 134

# %%
KerasModelHelper.get_model_layers_details_all(xception)
# Out:
# ...
# Total 134 layers details are collected.
#       Id               LayerName                    Type Filters  \
# 0      0                 input_2              InputLayer       0
# 1      1            block1_conv1                  Conv2D      32
# 2      2         block1_conv1_bn      BatchNormalization       0
# 3      3        block1_conv1_act              Activation       0
# 4      4            block1_conv2                  Conv2D      64
# 5      5         block1_conv2_bn      BatchNormalization       0
# 6      6        block1_conv2_act              Activation       0
# 7      7         block2_sepconv1         SeparableConv2D     128
# 8      8      block2_sepconv1_bn      BatchNormalization       0
# 9      9     block2_sepconv2_act              Activation       0
# 10    10         block2_sepconv2         SeparableConv2D     128
# 11    11      block2_sepconv2_bn      BatchNormalization       0
# 12    12               conv2d_95                  Conv2D     128
# ...

# %%
KerasModelHelper.get_model_input_image_shape_info(xception)
# Out:
# Now getting very first layer from model..
# The layer Input Shape is (None, 299, 299, 3)
# You would need to import image of this size - (299, 299, 3)
# (None, 299, 299, 3)
